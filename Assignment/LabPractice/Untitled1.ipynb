# %%
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 3.10.5

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([1, 2, 3, 8])
ypoints = np.array([3, 12, 1, 43])

# %%
plt.plot(ypoints, marker = 'o')
plt.show()
